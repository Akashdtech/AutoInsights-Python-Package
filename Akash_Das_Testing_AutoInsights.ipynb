# %%
# !pip install git+https://github.com/Akashdtech/AutoInsights-Python-Package.git
# Out:
# ...
#   Cloning https://github.com/Akashdtech/AutoInsights-Python-Package.git to /tmp/pip-req-build-y0_l15dq
#   Running command git clone --filter=blob:none --quiet https://github.com/Akashdtech/AutoInsights-Python-Package.git /tmp/pip-req-build-y0_l15dq
#   Resolved https://github.com/Akashdtech/AutoInsights-Python-Package.git to commit 45291e4bcf2643460f27d0c1be2133eacb2156e5
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for autoinsights: filename=autoinsights-0.1-py3-none-any.whl size=5151 sha256=965381c9ce9096b3d4805a43d43e62d94038f3ef67f5c0b6e90d315a252ca9aa
#   Stored in directory: /tmp/pip-ephem-wheel-cache-3zwzaxhv/wheels/fe/60/be/ab1057745de731c0bfcb63d03f9c0f3c10aa6c8cc23345a66d
# Successfully built autoinsights
# ...

# %%
from autoinsights import AutoInsights
import pandas as pd

# Load dataset
df = pd.read_csv("/content/StudentPerformanceFactors.csv")

# Initialize AutoInsights
insights = AutoInsights(df)

# Explore dataset (prints summary statistics, missing values, and sample records)
insights.explore_dataset()
# Out:
# Dataset Info
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6607 non-null   int64
#  1   Attendance                  6607 non-null   int64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6607 non-null   int64
#  6   Previous_Scores             6607 non-null   int64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6607 non-null   int64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
insights.plot_histograms()
insights.plot_boxplots()

insights.plot_correlation_heatmap()
insights.plot_pairplot()

insights.plot_categorical_counts()
insights.plot_bar_charts()
insights.plot_pie_charts()

# %%
df
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0                23          84                  Low                High
# 1                19          64                  Low              Medium
# 2                24          98               Medium              Medium
# 3                29          89                  Low              Medium
# 4                19          92               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602             25          69                 High              Medium
# 6603             23          76                 High              Medium
# 6604             20          90               Medium                 Low
# 6605             10          86                 High                High
# 6606             15          67               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
# For Numerical Columns>

insights.plot_histogram("Hours_Studied")
insights.plot_line_plot("Attendance", "Exam_Score")
insights.plot_scatter_plot("Previous_Scores", "Hours_Studied")
insights.plot_boxplot("Exam_Score")

# For Categorical Columns>

insights.plot_categorical_count("School_Type")
insights.plot_bar_chart("Parental_Involvement")
insights.plot_pie_chart("Motivation_Level")
